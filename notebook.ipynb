# %%
#!pip install --user --upgrade requests beautifulsoup4 lxml html5lib==1.0b8

import os
import json
import requests
from uuid import uuid4
from bs4 import BeautifulSoup


class PttCrawler:
    
    def __init__(self, board, page, write=False):
        self.ptt_url = 'https://www.ptt.cc'
        self.board = board
        self.page = page
        
        self.session = requests.Session()
        self.session.cookies.update({
            'over18': '1'
        })
        
        self.write = write
        
    def run(self):
        
        url = self.ptt_url + '/bbs/' + self.board
        post_link_list = self.fetchPostLinkList(url)
        post_list = [self.fetchPost(post_link) for post_link in post_link_list]
        
        #for post in post_list:
        #    print(post)
        
        #NB self is never paszsed as an argument
        
        return post_list
        
    def fetchPostLinkList(self, url):

        #resp = requests.get(
        #    url,
        #    cookies = self.session.cookies
        #)
           
        resp = self.session.get(
            url
        )
        
        soup = BeautifulSoup( resp.text.encode( "utf-8" ), "lxml" )

        post_list = soup.find('div', {'class': 'r-list-container action-bar-margin bbs-screen'})
        link_list = [tag.get('href') for tag in post_list.find_all('a')]
        
        if self.page > 0:
            paging_group = soup.find('div', {'class': 'btn-group btn-group-paging'})
            previous_link = self.ptt_url + paging_group.find_all('a')[1].get('href')
        
            self.page -= 1
            previous_post_link_list = self.fetchPostLinkList(previous_link)
            #BECAUSE IT OPERATES INSIDE THE CLASS DEFINITION self SPECIFIES THE METHOD ("NOT THE ARGUMENTS")
            if previous_post_link_list:
                link_list.extend(previous_post_link_list)
        
        return link_list
    
    def fetchPost(self, url):

        url = self.ptt_url + url

        resp = self.session.get(
            url
        )
        
        soup = BeautifulSoup( resp.text.encode( "utf-8" ), "lxml" )
        
        metadata = soup.find_all('div', {'class': 'article-metaline'})
        
        try:
            author = metadata[0].find('span', {'class': 'article-meta-value'}).text # find() RETURNS AN OBJECT WITH text MEMBER
        except:
            author = None
        
        try:
            title = metadata[1].find('span', {'class': 'article-meta-value'}).text
        except:
            title = None
        
        try:
            date = metadata[2].find('span', {'class': 'article-meta-value'}).text
        except:
            date = None

        try:
            content = metadata[-1].next_sibling # [-1] STANDS FOR LAST OF THE LIST
        except:
            content = None

        return {'title': title, 'author': author, 'date': date, 'content': content}

# %%
instance = PttCrawler('Gossiping', 3)
post_list = instance.run()
for post in post_list:
    print(post)
# Out:
# {'date': 'Thu Dec 21 15:05:27 2017', 'title': '[ＦＢ] 柯文哲 一起來玩「奔跑吧！台北」', 'author': 'Philethan (Ethan)', 'content': '\nＦＢ卦點說明：（'}
# {'date': 'Thu Dec 21 15:05:42 2017', 'title': '[新聞] 搶救空污 政院宣布2030市區公車全面電動化', 'author': 'paetix (少冰微糖)', 'content': '\n\n1.媒體來源:\n'}
# {'date': 'Thu Dec 21 15:06:03 2017', 'title': '[問卦] 女森是不是無法下半身思考所以輸男森', 'author': 'laser789 (南崁彭于晏)', 'content': '\n\n很多人都說男森下半身思考\n\n這應該是優點吧\n\n代表除了大腦還多一個下體來思考\n\n雙核心處理器的概念\n\n所以女森被罵沒大腦 沒邏輯是不是這個原因\n\n有沒有八卦？\n\n--\n'}
# {'date': 'Thu Dec 21 15:06:15 2017', 'title': 'Re: [問卦] 有沒有下床需要30分鐘的八卦', 'author': 'blackzero1 (瘦宅)', 'content': '\n'}
# {'date': 'Thu Dec 21 15:08:21 2017', 'title': '[問卦] 有沒有邏輯很好數學不好的', 'author': 'david190 (david)', 'content': '\n很多法官 邏輯很好\n\n大多數 不是台大畢業的\n\n一些甚至是同等學力考上的\n\n這些人邏輯超強\n\n\n數學不太好\n\n\n所以說 邏輯好 不等於數學好\n\n數學好 也不等於 邏輯好\n\n因為很多數學好的科學家 都很跳 跳躍式的講話思維 直觀超強 不管過程的也有\n\n所以說 邏輯 不等於 數學 反之亦然\n\n\n以後大家別用 數學好 等於 邏輯好 在那邊文字獄文科們了好嗎? 懂~就叫一聲聽聽~\n\n--\n'}
# {'date': 'Thu Dec 21 15:09:28 2017', 'title': '[問卦] 有人還記得Kony 2012嗎', 'author': 'bigtien6292 (bigtien)', 'content': '\n一個記者幫非營利組織拍的紀錄宣傳片\n\n主要在說有個烏干達軍閥Kony奴役兒童當兵或當性奴\n\n在2012年超紅，不問世事的美國人都一半以上知道這件事\n\n一開始迴響很大，一堆明星支持，歐巴馬還派兵\n\n後來好像評價墜落，說是沒有反應事實而且募款去向不透明\n\n現在這個活動怎麼樣了？ Kony是被抓還是在爽？\n\n有人還記得這些事嗎\n\n--\n'}
# {'date': 'Thu Dec 21 15:10:10 2017', 'title': '[問卦] 如果支那打過來要躲那裡比較安全?', 'author': 'heartsilent (心靜自然涼)', 'content': '\n如果有天支那真的打過來了\n\n我們一般宅平凡 不想被大屠殺的話\n\n應該要躲那裡?躲尼姑寺?\n\n他們應該不敢亂動尼姑吧?\n\n有卦嗎\n\n--\n'}
# {'date': 'Thu Dec 21 15:10:30 2017', 'title': '[問卦] 博人是富幾代？', 'author': 'takashi01 (廢文小王子)', 'content': '\n\n我肥肥啦\n\n肥肥好奇\n\n鳴人也算是繼承他爸黃色閃電的優良血統\n\n而他爸是四代火影\n\n但是鳴人的血統好像又可追朔到大筒木一族\n\n是大筒木羽衣也就是六道仙人的小兒子的轉世\n\n而小兒子的後代子孫代代都是千手一族\n\n而鳴人既然是轉世應該也算千手一族的後繼者吧？\n\n作為千手一族的後繼者 博人可以算是富幾代？\n-----\nSent from JPTT on my iPhone\n\n--\n'}
# {'date': 'Thu Dec 21 15:10:33 2017', 'title': '[問卦] 有沒有分辨修圖的八卦', 'author': 'nsysu5566wow (西灣五六哥~哇嗚( ′-`))', 'content': '\n\n胎嘎猴\n\n最近海軍出了一本公益月曆阿，裡面有豪多妹紙\n\n但是蘋果說修圖修很大\n'}
# {'date': 'Thu Dec 21 15:10:55 2017', 'title': 'Re: [問卦] 臺灣如果要拍穿越劇要拍哪個年代', 'author': 'jayday (nass)', 'content': '\n'}
# {'date': 'Thu Dec 21 15:11:43 2017', 'title': 'Re: [新聞]中國官媒為王炳忠、侯漢廷聲援:該把台獨', 'author': 'todao (心裡有數)', 'content': '\n那個....在台灣主張獨立或統一都不會被抓，那是言論自由。\n\n今天會被傳喚，是因為檢調要了解有無違法(國安法)，跟主張統一無關.....\n\n一下對檢調的合法調查大喊白色恐怖，一下又說台獨應該被抓。\n\n這......XDDD\n\n--\n'}
# {'date': 'Thu Dec 21 15:13:55 2017', 'title': 'Re: [問卦] 勞斯萊斯怎不出家用電器？', 'author': 'tending (南港林威助)', 'content': '\n'}
# {'date': 'Thu Dec 21 15:14:04 2017', 'title': 'Re: [新聞] 稅改案國會過關 川普獲重大立法首勝', 'author': 'KINMENKING (亂世狂刀)', 'content': '\n推 davideason: 美國經濟要井噴惹                                    12/21 10:31\n\n兩次世界大戰到冷戰，讓美國成為「最大甚至唯一的贏家」，美國財團從此成為大魔王\n\n當習近平撐過數次股災後，美國卻馬上全面發動習近平包圍，甚至準備在南海開戰\n\n歐盟想把中東問題解決、花錢讓難民回家時，高喊歐盟大一統的時候\n\n美國卻承認耶路撒冷是以色列的首都，甚至直接嗆聲全世界「閉嘴」\n\n\n而川普上任後的美國看情勢不對，馬上就想搞「關稅壁壘」，然後北韓就核爆跟射了...\n\n面對中、俄扶植的北韓這種極端國家，美國再強大也不得不低頭，立刻從敘利亞退出\n\n更不敢在習近平19大「登基」前對中國有所制裁，也把稅改案大幅的延後到現在通過\n\n\n美國的戰略就是希望能夠把北韓核武問題解決掉，但不想讓韓國統一而讓南韓倒向中國\n\n但南韓看到機會就想找習近平解決「北韓」來推動南北韓統一，這就大出美國的意料之外\n\n也因此川普整天喊要開戰，南韓卻一直強調「要經過南韓同意」才能開戰\n\n\n而北韓高層己經知道「被統一」勢不可擋，所以美國態度軟化~~北韓的態度卻更加強硬\n\n就是要讓美國帶頭對北韓的制裁繼續加大，讓北韓政權「自然瓦解」來推動兩韓統一\n\n而美國雖然幹在心裡，但是北韓堅持不肯棄核，那美國也就只有制裁到北韓瓦解為止了\n\n\n至於在兩岸部份也沒好到哪去，美國不會保衛台灣~~但也絕對不會讓中國有機會打台灣\n\n所以釣魚台美日安保、南海自由航巡，都是把「爭端擴大」讓中共需要台灣「共爭海權」\n\n\n但是美國稅改跟優惠招商，也會讓中國減稅、推優惠，那麼兩岸對立~~台灣就必死無疑\n\n現在台灣的處境就跟以前的菲律賓一模一樣，信美國者...必死無疑...\n\n--\n'}
# {'date': 'Thu Dec 21 15:14:19 2017', 'title': 'Re: [問卦] 哈韓迷妹是不是一堆智障？', 'author': 'sevenzgod (7z)', 'content': '\n我才覺得八卦版智障一堆\n\n低能兒\n\n韓飯的偶像死了\n\n\n\n就跟最愛的女優宣布引退\n\n遊戲公司被ea併購一樣\n\n不能將心比心一下嗎\n\n今天新垣結衣死掉了\n\n八卦版會有多少人崩潰\n\n\n明明就不同文化和崇拜程度\n\n硬是要去反別人\n\n腦子是不是有洞啊\n\n就跟肥宅最愛的聲優新田惠海下海拍av不是一堆也悲憤宅爆走\n\n還有一堆可以舉例\n\n哈韓迷妹迷韓國人是真實的\n\n八卦肥宅迷動漫是假的 動畫軟體\n\n懂?\n\n-----\nSent from JPTT on my Asus ASUS_Z00AD.\n\n--\n\n--\n'}
# {'date': 'Thu Dec 21 15:14:55 2017', 'title': '[新聞] 恐攻？澳洲休旅車衝撞19人倒地 「人體四', 'author': 'JonLester34 (冏˙雷斯特)', 'content': '\n\n\n\n恐攻？澳洲休旅車衝撞19人倒地 「人體四處飛」\n\n\n澳洲墨爾本佛林德街（Flinders Street）火車站外今天發生汽車衝撞行人事件，案發現\n場人車眾多，有多名行人倒地。澳洲《世紀報》報導，多達19人受傷。\n\n現場畫面顯示，一輛白色四輪傳動休旅車旁，有多人倒在地上。一名目擊者說，車輛「撞\n倒所有人，人體四處飛」。警方警告民眾遠離案發地區。急救單位指出，有2名傷者被送\n往醫院，包括1名頭部受重傷的幼兒園孩童。\n\n維多利亞省警方表示，駕駛已被捕。警方尚未證實此案是否與恐怖攻擊有關。\u3000（國際中\n心／綜合外電報導）\n\n'}
# {'date': 'Thu Dec 21 15:15:25 2017', 'title': 'Re: [問卦] 肯亞詐欺犯在台灣會被判多重?', 'author': 'cmq29 (cmq29)', 'content': '\n目前尚無在肯亞從事詐騙的國人被審判，無從比較，這是今年的一則新聞，同一詐騙集團\n被破獲，在臺灣跟中國被捕的歹徒待遇天壤之別\n\n台灣被捕的：         主  嫌             台灣判    2年6個月\n            在台取款的車手 & 其他成員   台灣判 3個月 ~ 1年6個月\n\n中國被捕的：同集團赴中國取款的台灣車手  共匪判 8年6個月  ←←比臺灣刑度 重了5倍以上\n\n難怪從事詐騙的台籍垃圾要回臺灣，因為臺灣真是寶島............................\n\n1.媒體來源: UDN 聯合報\n2.完整新聞標題:  詐欺車手在大陸判刑8年半 集團在台主嫌才判2年半\n3.新聞連結 (或短網址):  '}
# {'date': 'Thu Dec 21 15:15:23 2017', 'title': '[新聞] 改變戰略 日本傳準備與中國一帶一路合作', 'author': 'asnh (asnh)', 'content': '\n    改變戰略 日本首相安倍晉三傳準備與中國一帶一路合作\n\n\n    日本時報(Japan Times)18日引述共同社報導，日本首相安倍晉三(Shinzo Abe)基本上\n已決定推動與中國大陸的「一帶一路」計畫合作，使得安倍先前提出的「自由開放的印度\n─太平洋區域戰略」出現轉向，從牽制中國成為以日中合作為基礎。\n\n    根據報導，日本政府已向中方傳達安倍當前推動印太戰略的目標，以及該戰略對北京\n提出的跨國基礎建設發展計畫─「一帶一路」的正面效益。\n\n    根據一名消息來源說，「我們的戰略是要透過與印太區域內的國家協調，達成國際\n社會的穩定與繁榮。」「這項戰略應該能對推動一帶一路計畫有貢獻。」\n\n    日方消息來源並指出，由於日中兩國的政策涵蓋區域有重疊，日本正在考慮，要支持\n日中兩國企業的聯合基礎建設開發計畫與業務推廣。\n\n    根據消息來源的說法，安倍相信，由於中國在全球經濟與安全議題的角色日益加重，\n日本有必要改善與中國的外交關係。\n\n    安倍晉三現在的目標，是要努力達成自由開放的印太戰略，同時合作推進北京的\n一帶一路計畫。日本也希望中國國家主席習近平訪日的計畫能儘早實現。\n\n    安倍於去年8月揭露他的印太政策戰略，當時希望藉由強調基於法治達成海上秩序的\n重要性，來限制中國在東海與南海日益擴張的海事行動。\n\n\n\n中央廣播電臺\n\n'}
# {'date': 'Thu Dec 21 15:16:13 2017', 'title': '[協尋] 12/21 08:15台北環河北路敦煌碼頭附近', 'author': 'mrsmiller (Tiffany)', 'content': '\n12/21 08:15上班途中在台北環河北路敦煌碼頭附近，\n車子輾到一個電動鑿子機的鑿子（長型鐵製拆房子用的尖銳物），\n穿刺過車子底盤、內裝，車子破一個大洞、內外通風，\n懇求當時行經該路段目睹掉落的好心人提供行車記錄器...感激不盡...\n'}
# {'date': 'Thu Dec 21 15:16:40 2017', 'title': '[問卦] 波函數塌陷是在塌什麼', 'author': 'SupCat (FBI WARNING)', 'content': '\n\n有名的薛丁格的貓故事裡\n告訴我們 當測量者觀測的此刻\n波函數會塌陷\n\n請問一下 函數不就是一個表示式嗎\n像f(x)=9x^2+8x+7這樣\n\n塌陷是在塌陷什麼\n又不是隧道 挖一挖會塌陷埋死人\n用詞會不會太玄妙了？\n\n--\n'}
# {'date': 'Sat Nov 11 23:55:13 2017', 'title': '[公告] 八卦板板規(2017.11.11)', 'author': 'Kay731 (K少)', 'content': '\n\n╭─────────────────────────────────────╮\n│ 本板為PTT八卦板，文章、推文及板務處理原則均依循中華民國法律、站規規範發\u3000│\n│ 文者，不得因不知相關板規而免卻責任。                                     │\n╰─────────────────────────────────────╯\n\n'}
# {'date': 'Sun Dec 10 13:09:40 2017', 'title': '12/09 台南三媽臭臭鍋前車禍目擊', 'author': 'vivismile (薇薇一笑)', 'content': '\n幫朋友代po\n死者是朋友的表妹，請大家幫幫忙！\n\n-\n\n請各位鄉民們幫幫忙\n找到一場車禍事故的行車記錄器、監視器畫面或目擊者\n表妹出車禍，已宣告死亡，\n整個下半身跟骨盆都嚴重扭曲變形\n但是無法釐清肇事責任，\n肇事者佔用機車道，表妹與她男朋友閃避不及而擦撞飛出\n剛好後面一台711物流車行駛過來，釀成悲劇\n時間：12/9 0:50-1:00之間\n地點：台南市小東路138號，三媽臭臭鍋前\n聯絡電話：0986205313\n\n\n真的非常希望可以找到目擊證據 謝謝！！\n\n\n\n—\n\n目前家屬已經找到證據相關影片交由警方\n真的非常感謝大家幫忙！！！\n\n--\n'}
# {'date': 'Sat Dec 16 20:08:08 2017', 'title': '[協尋] 12/16 台北市民大道金山北路口車禍', 'author': 'someoneelse ( )', 'content': '\n\n請廣大的鄉民們幫幫忙\n協尋一場車禍事故的行車紀錄器影片\n我弟弟與他女友在此路口騎車往南直行時\n遭違規左轉的汽車撞到\n兩人的傷勢都很嚴重\n肇事者說行車記錄器沒電無行車資料\n時間：12/16 17:00-17:20 左右\n地點：市民大道三段與金山北路口\n如果有善心人士協助提供的話\n請聯絡陳先生，電話0910327861\n謝謝\n-----\nSent from JPTT on my iPhone\n\n--\n'}
# {'date': 'Tue Dec 19 19:40:31 2017', 'title': '[協尋] 12月19日 晚上9點前後  高雄市明誠路 鼎', 'author': 'jokerndmc (小人物)', 'content': '\n\n昨晚(12/18)家人在明誠一路  鼎吉街口發生機車汽車車禍\n時間約晚上9點前後\n\n\n目前家人在加護病房觀察\n懇求當時在附近的好心人提供行車記錄器\n以釐清肇事原因\n感激不盡\n\n-----\nSent from JPTT on my Asus ASUS_Z012DA.\n\n--\n'}
# {'date': None, 'title': None, 'author': None, 'content': None}
# {'date': 'Thu Dec 21 14:52:27 2017', 'title': '[問卦] 好聽又好唱的中文歌？', 'author': 'Sron (沒暱稱)', 'content': '\n大家安安\n\n小弟最近有項作業\n\n要改歌詞還要唱\n\n可是平常很少聽中文歌\n\n不知道大家有沒有什麼推薦的\n\n--\n'}
# {'date': 'Thu Dec 21 14:52:54 2017', 'title': '[問卦] 理工宅不擅交際?', 'author': 'fa881819 (拜特)', 'content': '\n小弟有一些理工宅朋友\n\n不怎麼愛打扮 大多肥肥宅宅的\n\n穿搭感覺從國中到現在都是一致\n\n聊天不是debug就是實驗室\n\n再不然就是動漫\n\n但遇到女生的時候每個都超尷尬\n\n搔搔油油的頭 然後呵呵呵的笑\n\n不然就是自顧自講自己的 讓氣氛降到零點\n\n\n這樣算異性障礙嗎\n\n技能樹是不是點的不太平均\n\n--\n'}
# {'date': 'Thu Dec 21 14:53:27 2017', 'title': 'Re: [新聞] 「暫無暖氣但政策溫暖」 中共環保部挨轟', 'author': 'isaluku (山本君)', 'content': '\n'}
# {'date': 'Thu Dec 21 14:54:54 2017', 'title': '[問卦] 如果蘇菲說了會怎樣', 'author': 'rv0918 (Lee)', 'content': '\n\n大家午安\n\n各位肥宅中午有沒有把肚子塞飽啊？\n\n小弟剛剛在複習霍爾的移動城堡啦\n\n荒野女巫對蘇菲施展了變老的魔法\n\n並且告誡蘇菲不可以跟任何人說\n\n為什麼啊？\n\n另外還有荒野施展的是什麼魔法？\n\n為什麼蘇菲的外表會隨著心態而產生變化？\n-----\nSent from JPTT on my iPhone\n\n--\n'}
# {'date': 'Thu Dec 21 14:55:39 2017', 'title': 'Re: [新聞] 共機今又繞台！我方飛行員喊「回頭」', 'author': 'perceval (摸魚中)', 'content': '\n'}
# {'date': 'Thu Dec 21 14:57:41 2017', 'title': 'Re: [問卦] 有沒有下床需要30分鐘的八卦', 'author': 'todao (心裡有數)', 'content': '\n'}
# {'date': 'Thu Dec 21 14:58:27 2017', 'title': 'Re: [ＦＢ] 沈志霖(阿堅助理)柯P光榮城市內幕大公開', 'author': 'sdfzxc (萬般皆無)', 'content': '\n有網友轉貼過去，助理反應好大XD\n\n'}
# {'date': 'Thu Dec 21 14:58:49 2017', 'title': 'Re: [問卦] 有沒有下床需要30分鐘的八卦', 'author': 'Preach (溫哥華八弟)', 'content': '\n原文太多要錢推文\n\n在這回你一下,建議你去看免疫風濕科,可能是僵直性脊椎炎\n\n個人也有這方面的困擾,以前高中打籃球打一打痛到沒辦法彎下去綁鞋帶,以為打球腰傷\n\n冬天起床可能要花45分鐘身子熱了才能正常走動,然後每天痛到沒辦法專心上課\n\n\n中間骨科神經科都看了藥都吃了,沒用就是沒用,後來是在榮總被懷疑僵直性脊椎炎\n\n才被轉到免疫風濕科\n\n其實台灣好像蠻高機率的人有這個病的基因,只是有這個基因發不發作又是另一件事\n\n運氣好的人有這基因不發作也不用當兵,最慘的是沒這基因還發作的人,比如說我\n\n明明就是痛得要死,還是被判一般義務役...\n\n\n這病只有有錢人有資格得,因為不能久久持續一個動作,也不能長時間走路\n\n代表服務業你幾乎做不了,辦公室也要老闆願意讓你動不動就站起來走來走去伸展\n\n很多鄉民都在笑周杰倫逃兵,那是因為大多數人不知道這多痛\n\n套句我主治醫生的話,得這病的人很大機率會很聰明,因為每天痛覺刺激你的神經跟腦\n\n我不是專家我不知道他說對不對,但我確定你一醒來就會痛,痛到後面有天不痛你會覺得怪\n\n而目前無藥可醫,只能控制,像周杰倫那樣定時打個幾針生物激素（一針好幾千且沒健保）\n\n私人機構保險你也買不了\n\n\n唯一控制的方法就是每天拉筋做瑜珈、早睡、飲食正常、避免菸酒、同姿勢不要維持太久\n\n游泳也是醫生建議控制的方法,但永遠只是控制...\n\n還得忍受旁人的異樣眼光,冬天一冷有時候身體僵硬就痛得下不了床\n\n老闆會覺得你根本是睡過頭,同事也會覺得你上班動不動就站起來走來走去是在裝病\n\n這病根本就是讓你看清楚你在台灣的工作環境不會有機會了,除非你家裡有錢\n\n\n八掛點就是我從發病到現在人生只有幾天起床不背痛,就是前一天有抽大麻的時候\n\n取得是在溫哥華的藥用大麻店,然後現在本魯在澳洲當上班族,想在家工作就跟公司申請\n\n上班也是想去哪走走找靈感就可以去,去了老闆還願意借我車子或者補貼我交通費\n\n只能說台灣工作環境不適合自己啦\n\n--\n'}
# {'date': 'Thu Dec 21 14:59:21 2017', 'title': '[問卦] 跨年夜要約學妹去哪裡?', 'author': 'dudeboy (包莖俠)', 'content': '\n\n台北的煙火最有名\n\n高雄的演唱會也不錯\n\n或是要約她爬山看日出\n\n好煩惱喔 到底要約哪裡才不會被學妹打槍\n\n\n--\n'}
# {'date': 'Thu Dec 21 14:59:22 2017', 'title': '[問卦] 偶爾換一下路線是不是也不錯？', 'author': 'arrenwu (柊真雪超級可愛)', 'content': '\n\n大家平常生活做各種事情，比如買東西，\n長久下來應該都有一個固定路線。\n\n不過一直做同樣規劃，感覺久了也似乎有點枯燥。\n偶爾換一下路線，比如平常都是海老名線，偶爾走切繪線，是不是也滿不錯的？\n\n--\n'}
# {'date': 'Thu Dec 21 14:59:47 2017', 'title': '[問卦] 認真問文組男有比較帥嗎？', 'author': 'wen8278 (咖啡因重症患者)', 'content': '\n每次大家都說理組男不擅交際\n\n不知如何和異性相處 被騙的很多都理工宅\n\n所以 文組男真的有比較帥嗎？\n\n看我以前學校的管院男生\n\n生活都多采多姿 活動好多\n\n--\n'}
# {'date': 'Thu Dec 21 15:00:50 2017', 'title': 'Re: [爆卦] 王炳忠侯漢廷開記者會抗議', 'author': 'benothing (禹楓)', 'content': '\n幾個月前不是才一堆人在說莫忘「大是大非」\n\n黃世銘分案監聽，把進行中的案子跟馬英九匯報，\n還接受指示的將案情洩露給行政官員，\n結果被告的時候一天到晚跟覺青在吶喊「大是大非」\n\n\n這時候擺了明就是舔中的人被檢調請過去喝杯咖啡\n了解他到底寫了什麼書可以拿這麼多的稿費，還不用支付寶，\n帳冊是幫誰記的帳\n還有跟匪諜有交換什麼情報\n\n結果原來「大是大非」派的覺青突然吶喊程序正義\n我的老老老老天鵝啊！\n\n所以馬英九有罪嗎？有卦否？\n\n\n--\n'}
# {'date': 'Thu Dec 21 15:01:42 2017', 'title': 'Re: [新聞]台詐騙犯陸重判 國民黨：政府應讓犯嫌返台', 'author': 'allbs (喵嗚)', 'content': '\n'}
# {'date': 'Thu Dec 21 15:03:15 2017', 'title': 'Re: [問卦] 消滅機車族對台灣是好還是不好???', 'author': 'tigotigo5566 (鐵劍5566)', 'content': '\n說得非常好\n\n那政府應該要來個配套措施\n\n就是讓全民都買得起全新汽車。\n\n不然就會看到一群領22K的小孩子們，每餐吃一個波蘿麵包也沒配飲料，\n\n只為了買一部二手破車，搞不好開在路上拋錨，造成連環車禍，更危險啦。\n\n不然就要有大眾交通工具優或措施，比如說年薪一百五十萬以下者，搭乘大眾交通工具\n\n一律由政府全額補助。還有司機不得過勞，一天上班時間八小時，不然疲勞駕駛還是會\n\n車禍。\n\n\n拎北是很樂見啦，少子化、低薪、房價高漲、物價高漲政府都沒解決，\n\n讓人民越來越窮，現在連機車也不給騎，既然要禁機車，就先把上述問題改善。\n\n\n\n\n'}
# {'date': 'Thu Dec 21 15:04:11 2017', 'title': '[新聞]   勒斃老婦駕車丟屍海邊\u3000嫌駕棄屍車輛넱', 'author': 'Tarsun (油好多)', 'content': '\n'}
# {'date': 'Thu Dec 21 15:04:45 2017', 'title': 'Re: [問卦] 高中物理難度是不是太低了', 'author': 'QQ890829 (看三小 關你們屁事)', 'content': '\n大家豪 我是可愛的小妹\n\n現役高中生可以回這篇吧？\n\n嗯 高一生高二時 選惹理組\n\n啊現在高三喇高三\n\n課表就是國英數物化\n\n幹 物理超難的好不好幹\n\n被當了兩個學期  人家都去修回來了QQ\n\n其實說難到是還好吧\n\n絕大因素4我迷U認真讀\n\n但是R  我很多同學好像很認真  啊也就考那樣\n\n所以其實我也不知道難不難...\n\n\n倒是現在考模擬考很有感\n\n你會覺得物理好像是自然科裡面最簡單der\n\n\n我們老師是自編講義喇\n\n上課速度快的靠北\n\n然後我覺得現在這樣的難度就...夠了啦QQ\n\n\n'}
# {'date': 'Thu Dec 21 15:04:52 2017', 'title': '[新聞] 檢調急追電腦、手機 王炳忠恐再遭約談', 'author': 'helikon (赫利羹)', 'content': '\n1.媒體來源:\n'}
# {'date': 'Thu Dec 21 15:04:52 2017', 'title': 'Re: [問卦] 年輕人工作時間很愛滑手機是在？？？', 'author': 'SIROMa9 (職業詐欺師)', 'content': '\n這我也有疑惑\n上班時間規定不能用手機\nOK我接受 反正肥宅也沒朋友可以line\n公司群組也排擠我 9成電話都是推銷或打錯的\n不用就不用\n\n但憑什麼下班要接老闆電話回line\n有錢嗎？\n有錢嗎？蛤！ 共啊\n\n\n'}
# {'date': 'Thu Dec 21 15:05:10 2017', 'title': '[問卦] 電話秒掛', 'author': 'qscxz (奈米哥)', 'content': '\n最近偶爾會接到手機號不認識的打來\n\n響了約15秒也不掛斷\n\n只好接起來聽看看是啥\n\n但一接通對方就掛掉\n\n搞毛阿\n\n看來電號碼是台灣的\n\n大大們知道這種打來硬要你接通卻不講話是要做甚麼\n\n--\n當個稱職的鄉民有三大條件   嘴砲\n                           引戰\n                           湊熱鬧\n\n--\n'}
# {'date': 'Thu Dec 21 15:05:24 2017', 'title': 'Re: [問卦] 理工宅不擅交際?', 'author': 'opqr9988 (等吧QQ)', 'content': '\n大家安安\n\n我覺得理工宅不一定交不到女友\n而是妳身邊的女生都太膚淺了\n\n舉例來說我學姐，每天都一直找我聊天\n除了一些無聊的小情小愛，還會找我討論電磁學，甚至還會跟我一起算海森堡矩陣，偶爾還會約說要跟我做愛\n\n我是覺得理工宅身邊一定也會有可以懂你的女孩\n\n'}
# {'date': 'Thu Dec 21 14:42:35 2017', 'title': 'Re: [問卦] 年輕人工作時間很愛滑手機是在？？？', 'author': 'Phoenix9 (燄燄)', 'content': '\n'}
# {'date': 'Thu Dec 21 14:43:31 2017', 'title': '[問卦] 哎喲，覺青484都有從政夢？', 'author': 'moshenisshit (嘻嘻)', 'content': '\n本肥今天又看到一個覺青臉友發文，\n\n說他申請加入某個號稱第三勢力的小黨，\n\n還順便附上了黨證的照片作為證明。\n\n\n自從大腸花以來已經是第七個覺青臉友了，\n\n好像幾乎每個覺青都想要從政吼，\n\n都希望把反核、女權、甲權、廢死立法。\n\n\n哎喲，覺青484都有從政夢啊？\n\n--\n'}
# {'date': 'Thu Dec 21 14:43:37 2017', 'title': '[問卦] 周杰倫為什麼回不去以前的曲風了？', 'author': 'saipipi (雷神)', 'content': '\n'}
# {'date': 'Thu Dec 21 14:43:47 2017', 'title': 'Re: [新聞] 肯亞詐騙案台灣主嫌\u3000遭中國法院重判15年', 'author': 'raxxar82 ( )', 'content': '\n空中監獄詐騙慣犯 遣返4年還在騙\n\n狗改不了吃屎！詐欺通緝犯詹誌誠等13人曾在菲律賓組詐騙集團，被台菲警方破獲，原要\n遣送中國，經我方爭取後以「空中監獄」方式集體遣返台灣，這13人被判刑1年到6年拒不\n到案，還租別墅當機房擴大行騙，新竹市警方前天赴宜蘭攻堅，逮30歲詹男等33人，宜蘭\n檢方訊後將13名通緝犯解送歸案，其餘均聲押獲准。\n\n詹誌誠等人在機場看見華航與長榮包機，紛紛大喊「就算在台灣被關也比較幸福」。詹男\n集團13人返國後，詹被判1年，餘12人分別判1到6年，13人拒絕到案執行而被通緝，還重\n啟爐灶，透過架設電腦網路電信機房，打電話詐騙。\n\n警方指出，台灣的詐欺刑期太輕，一般多是1年徒刑起跳，若無法取得被害人筆錄，大多\n可獲緩刑；若依中國法律宣判，凡構成詐欺罪，就得面對10年以上重刑。\n\n對於不到案服刑，警方建議，司法改革應針對此，修正為強制被告須到庭聆判，有罪確\n定，就當庭執行，才能遏止。\n\n'}
# {'date': 'Thu Dec 21 14:44:02 2017', 'title': 'Re: [問卦] 高中物理難度是不是太低了', 'author': 'JugarXE (JugarXE)', 'content': '\n'}
# {'date': 'Thu Dec 21 14:44:23 2017', 'title': 'Re: [問卦] 洪仲丘有11萬人錄音帶會有多少人的卦?!', 'author': 'rote (ROTE)', 'content': '\n'}
# {'date': 'Thu Dec 21 14:46:57 2017', 'title': 'Re: [問卦] 虎航空姐素質屌打其他', 'author': 'tigotigo5566 (鐵劍5566)', 'content': '\n聽你在放__\n\n拎北今年十月才坐虎航去沖繩\n\n機艙裡服務的都是男的\n\n艮！整個傻眼！\n\n坐飛機出國，連看空姐的樂趣都沒有，難道虎航不用負責嗎？\n\n'}
# {'date': 'Thu Dec 21 14:47:01 2017', 'title': '[問卦] 有沒有資料結構的掛', 'author': 'MEKE0000 (豝☆即☆斬)', 'content': '\n大家午安\n想請問大家有沒有資料結構（Data Structure）\n\n\n\n這個看起來很簡單\n實際上東西很雜的掛呢?\n\n--\n'}
# {'date': 'Thu Dec 21 14:47:16 2017', 'title': '[問卦] 同事留起「下巴大鬍子」', 'author': 'cosmite (K)', 'content': '\n我有個同事單身很久 體型中等偏胖 之前以為他是動漫宅\n\n但他最近留起鬍子 '}
# {'date': 'Thu Dec 21 14:47:42 2017', 'title': '[問卦] 勞斯萊斯怎不出家用電器？', 'author': 'teddysue ()', 'content': '\n\n\n勞斯萊斯除了汽車\n\n在航空領域渦輪風扇發動機更是一絕\n\n很多產品都自稱XX界的勞斯萊斯\n\n那為何勞斯萊斯要讓別人吃豆腐\n\n論工藝、技術應該都不是難事\n\n而不自己在家電產品弄個吹風機、吸塵器\n食物攪拌機、打蛋器、電風扇  等等\n\n爸爸做家事同時也能感受尊絕不凡潮到飛天\n\n賣個八、九、十萬做出市場區隔\n\n相信會買單也是大有人在\n\n有掛嗎？\n\n\n\n\n\n\n\n--\n'}
# {'date': 'Thu Dec 21 14:47:49 2017', 'title': 'Re: [新聞] 廢英檢畢業「假門檻」！13校學生會齊發聲', 'author': 'wade6510 (真情不必多說)', 'content': '\n'}
# {'date': 'Thu Dec 21 14:48:20 2017', 'title': '[問卦] 剛剛媽媽打電話來說被騙了.....', 'author': 'coffee3698 (帥 太沉重)', 'content': '\n\n怎辦現在很生氣 很無奈\n家裡經濟狀況不是很好\n媽媽剛剛說對方學我學的很像\n然後他在帶小孩\n他去領兩萬塊\n買英雄聯盟序號給別人\n。。\n他打給我連求證都不求證\n我叫他去報案\n請問這個救的回來嗎\n整個好想哭\n認真問個\n\n\n\n-----\nSent from JPTT on my HTC_D728x.\n\n--\n'}
# {'date': 'Thu Dec 21 14:48:23 2017', 'title': 'Re: [新聞] 政院強調勞基法沒修惡\u3000 林美珠再上火線', 'author': 'opfish (coco)', 'content': '\n'}
# {'date': 'Thu Dec 21 14:49:44 2017', 'title': '[問卦] 被感應有災難覺得很幹要怎麼辦?', 'author': 'tspes40801 (tspes40801)', 'content': '\n乳題\n\n小弟最近被家人通知，他朋友在路過廟宇時強烈抖動\n\n俺家人就去廟宇擲茭，同行的只有俺家人甩出聖茭\n\n不知道為什麼俺家人什麼不提就是把我提出來\n\n聽說我會有災難，好像是地震和機車什麼的吧\n\n不過好像可以逃脫\n\n因為這樣機車就被禁了一個月還要回去廟裡問\n\n最近壓力就很大了，又碰上這些鳥事，還要空緊張\n\n覺得很幹，在座有沒有人可以幫小弟感應一下\n\n小弟到底要做什麼? 還是死定了?\n\n\n\n\n\n如果死定了也沒關係啦直接跟小弟說，反正小弟也沒女友，人生也不成功，好像也沒差\n，知道比較方便寫遺言跟好朋友和家人交代一下，謝惹。\n\n--\n'}
# {'date': 'Thu Dec 21 14:49:45 2017', 'title': 'Re: [問卦] 高中物理難度是不是太低了', 'author': 'arrenwu (柊真雪超級可愛)', 'content': '\n'}
# {'date': 'Thu Dec 21 14:50:02 2017', 'title': '[新聞] 「談戀愛等長大再說」 結果他後悔了...', 'author': 'dudeboy (包莖俠)', 'content': '\n1.媒體來源:自由時報\n\n2.完整新聞標題:「談戀愛等長大再說」 結果他後悔了...\n\n3.完整新聞內文:\n\n2017-12-21 14:33\n\n〔即時新聞／綜合報導〕為了考上好學校，找到好工作，許多台灣學生為了未來的理想目\n標努力念書。但近日有位網友在在PTT上PO文，表示從小父母師長告誡「要好好念書，不\n要談戀愛、看漫畫、打電動」，出社會後靠著學歷找到一份「餓不死」的工作，但卻認為\n學生時代為了念書犧牲掉很多東西，引起網友熱烈回應。\n\n台灣低薪問題普遍嚴重，甚至連名校畢業生的薪水都與理想薪資有落差。該名網友表示，\n自己被告誡「學生時期好好念書最重要，要娛樂等長大再說」，出社會後薪水也普普通通\n，但卻有點後悔當初這麼用功念書。\n\n該名網友提到，學生時代花了好多時間，讀了很多出社會後用不到，只為了在考試得到高\n分的知識，實在很想把當年「乖乖相信好好念書，以後才會出人頭地」的自己打醒，也感\n嘆自己沒有珍惜歲月，將注意力全部都集中在讀書上。\n\n許多網友紛紛回應，認為學生時期「比較後悔沒有好好念書」、「認真讀書後悔10年，不\n認真讀書後悔50年」、「後悔大學沒交女友」，不過也有網友豁達的說，「反正好好讀也\n讀不好，乾脆玩個開心」、「會念書又會玩的人多的是」。\n\n4.完整新聞連結 (或短網址):\n\n'}
# {'date': 'Thu Dec 21 14:50:02 2017', 'title': '[問卦] 有沒有商品被貨運司機弄丟的卦?', 'author': 'sag14221016 (蘭陵汁汁蛋)', 'content': '\n\n直接上我和賣家的聊天紀錄\n'}
# {'date': 'Thu Dec 21 14:50:53 2017', 'title': 'Re: [問卦] 虎航空姐素質屌打其他', 'author': 'leopika (龜山島田愛里壽)', 'content': '\n空姐我忘了啦\n\n但是我暑假坐虎航的時候\n\n因為走道有夠小，餐車一推出來人就不可能過走道了\n\n這班是旅行社包機，所以全機都有餐點要發\n\n在發餐點到飛機中間的時候\n\n一個空少要把餐車交接給負責後半的另外一個空少\n\n結果他就說\n\n「學長後面就交給你了」\n\n而且很帥☺\n\n--\n'}
# {'date': 'Thu Dec 21 14:51:29 2017', 'title': '[ＦＢ] 李慶鋒 柯市長常自誇很會還債 但是....', 'author': 'jenlei (大帥哥)', 'content': '\n20字掛點\ndpp議員李慶鋒壞壞\n怎麼可以黑阿伯勒\n過分耶！捷運基金這麼好用\n當然要好好靈活調度一下！\n\n內文\n'}
# {'date': 'Thu Dec 21 14:31:07 2017', 'title': '[問卦] 要怎麼讓有肝病的人別喝酒', 'author': 'Twatch (code)', 'content': '\n我朋友 很喜番喝酒\n\n可是他上次因為肝病  住院了\n\n醫師說絕對不要喝酒\n\n可是他還是一直偷偷喝酒\n\n這一次又住院\n\n我要怎麼勸他？\n\n--\n'}
# {'date': 'Thu Dec 21 14:31:28 2017', 'title': '[新聞] 政院強調勞基法沒修惡\u3000 林美珠再上火線', 'author': 'DoraGmon (哆啦G夢)', 'content': '\n政院強調勞基法沒修惡 \u3000林美珠再上火線：沒有開後門\n\n\n\n\n'}
# {'date': 'Thu Dec 21 14:31:43 2017', 'title': 'Re: [新聞]當性愛娃娃碰上人工智慧\u3000我們還需要真人?', 'author': 'coober ()', 'content': '\n當然需要真人\n\n至少在需求沒被滿足之前都要\n\n這些科學家蠻天真的\n\n以為只有性愛娃娃就能滿足全部男性\n\n錯！！！！大錯特錯！！\n\n\n\n要知道在廣大的社會裡面\n\n除正常男性外\n\n還寄居了大量的肥宅工具人\n\n他們因為胖 又油 基本上都是5cm\n\n給他們性愛娃娃跟給太監一樣\n\n所以他們轉而尋求其他方式得到肯定\n\n也就是當工具人 且當的還不亦樂乎\n\n但礙於社會觀感 怕被恥笑說是幫人養老婆\n\n所以偶爾會假裝出來仇女 或者說被騙\n\n就像許多女性一夜情被男友抓包後  為了撇清\n\n就要告一夜情對象強姦一般\n\n但其實深入頗析就會得知一個令人震撼的真相\n\n其實工具人根本就是自願的\n\n\n\n所以\n\n為了區隔市場\n\n科學家最好研發出具有使喚能力\n\n可以自動提出要求讓工具人去做\n\n這類的發明\n\n才能滿足工具人的需求\n\n畢竟 工具人就是愛被使喚\n\n你不使喚他們 你們匯渾身不舒服咧\n\n--\n'}
# {'date': 'Thu Dec 21 14:32:09 2017', 'title': '[新聞] 2035起禁售燃油車 行政院：技術已有突破', 'author': 'MikaHakkinen (一人中風，全家發瘋)', 'content': '\n\n自由時報 '}
# {'date': 'Thu Dec 21 14:33:37 2017', 'title': '[問卦] 有5566接班人—武虎將的八卦嗎', 'author': 'bucketface (bucketface)', 'content': '\n如題\n武虎將 知名台灣男團\n成員有 胡宇威 博焱 寺惟宏正 班傑 紹祥\n代表作為終極三國\n有沒有武虎將的八卦啊\n他們是5566的接班人嗎\n\n--\n'}
# {'date': 'Thu Dec 21 14:34:26 2017', 'title': '[新聞] 用數字說話 美國稅改究竟能幫人減多少稅', 'author': 'Articuno (小霞)', 'content': '\n'}
# {'date': 'Thu Dec 21 14:34:51 2017', 'title': 'Re: [問卦] 消滅機車族對台灣是好還是不好???', 'author': 'HongYang (PlasticSheep)', 'content': '\n'}
# {'date': 'Thu Dec 21 14:34:50 2017', 'title': '[問卦] 念能力是不是偷抄替身使者?', 'author': 'newwer (ももたまい)', 'content': '\n最近在看獵人，發現念能力設定根本偷抄替身使者\n\n念使用者各自有各自特殊的能力跟必殺技，概念跟替身能力有87%像\n\n強化系怪力小傑=不會時停的白金之星\n\n奇犽操控電=嗆紅辣椒\n\n貪婪之島炸彈魔=吉良吉影\n\n有沒有獵人偷抄JOJO的八卦?\n\n--\n'}
# {'date': 'Thu Dec 21 14:34:57 2017', 'title': '[問卦] 年輕人工作時間很愛滑手機是在？？？', 'author': 'oppo5566 (5566)', 'content': '\n\n只會抱怨低薪，\n\n結果一看上班的時候常常在滑手機，\n\n這樣有什麼資格要求調高薪水？？\n\n認同請給噓  噓醒這些年輕人！\n\n--\n'}
# {'date': 'Thu Dec 21 14:35:00 2017', 'title': 'Re: [新聞] 人體自燃？男突起火內臟都燒掉', 'author': 'CavendishJr (花將軍)', 'content': '\n\n\n一定是某種病毒\n\n對人體細胞進行暗示\n\n導致細胞自燃\n\n我有親眼看過一個銀髮大奶妹\n\n被病毒暗算，結果就自燃死亡了\n\n\n\n\n--\n'}
# {'date': 'Thu Dec 21 14:35:01 2017', 'title': '[問卦] 如果台灣實施推恩令的八卦？', 'author': 'zxc445567 (飄飄)', 'content': '\n如題 我們都知道漢朝時諸侯尾大不掉\n\n漢武帝時頒布推恩令來慢慢削弱諸侯勢力\n\n如果台灣也實施推恩令的話\n\n那種人需要被裁弱的？\n\n有沒有這一類的八卦？\n\n--\n'}
# {'date': 'Thu Dec 21 14:35:12 2017', 'title': '有沒有steam上有人送你遊戲的八卦阿', 'author': 'markvend (馬克芬德)', 'content': '\n在steam 上有人說要送遊戲給我～\n\n直接丟了序號給我\n\n才剛認識不久的美國人\u3000手上好像真的很多遊戲\n\n是個遊戲收藏家\u3000還是蒐藏特務\n\n直接給了我兩款遊戲～也不知道到底能不能用？\n\n就說他買了兩份\u3000叫我試試看\u3000說真的很不錯的遊戲\n\n有神人有經驗\u3000知道相關八卦的嗎\n\n要是真的能用的話好像也不錯....\n\n我應該要試試看嗎～\n\n--\n'}
# {'date': 'Thu Dec 21 14:35:30 2017', 'title': '[問卦] ubi為什麼一直送遊戲', 'author': 'dudeboy (包莖俠)', 'content': '\n\n上個月沒領到看門狗\n\n這星期又送了\n\n可以這樣送了又送嗎? 當我們是乞丐嗎?\n\n我想玩全境封鎖榮耀戰魂野境 哪時候會送啊?\n\n--\n'}
# {'date': 'Thu Dec 21 14:36:41 2017', 'title': 'Re: [問卦] 虎航空姐素質屌打其他', 'author': 'puput (哈亞多)', 'content': '\n最強的是威航\n\n沒有之一\n\n都長的青春亮麗又可愛\n\n每個都長的真的很瘦 但又不會太乾\n\n應該是真的有特別挑過\n\n再加上是穿緊身長褲 身材更是被襯托出來\n\n也不會死板板的還會主動跟你講話\n\n起飛前的安全表演 沒錯就是表演\n\n然後後來的免稅商品走秀\n\n拿威熊跟乘客拍照\n\n都很有趣\n\n然後位子又很大 價格又便宜\n\n再強調一次\n\n威航是最強的廉航 沒有之一\n\n還我熊阿!!!!!!\n\n\n\n'}
# {'date': 'Thu Dec 21 14:37:18 2017', 'title': '[問卦] 是不是每句話加上兄弟就變支那話了', 'author': 'monocyte123 (單核球123)', 'content': '\n單核球帥哥\n\n淘寶買貨人家都不送\n\n打算跟他求情一下：\n\n老鐵同志呀亲\n你那個貨怎麼不送我們台灣兄弟亲\n你這樣不就承認我們主權獨立了嗎兄弟亲\n是國人就發貨吧兄弟亲\n包邮沒毛病吧  亲\n\n\n不知道這樣說有沒有用ㄏㄏ\n\n--\n'}
# {'date': 'Thu Dec 21 14:38:36 2017', 'title': '[問卦] 貓貓喜歡摸胸部嗎？', 'author': 'Lumial020 (廢貓文專用帳號)', 'content': '\n\n是這樣的\n\n本城武剛剛想要拍\n\n貓貓咬我手手的照片來發文嘻嘻\n\n結果不管怎麼揉捏他的奶\n\n貓貓看起來\n\n卻\n\n一臉很爽！？\n'}
# {'date': 'Thu Dec 21 14:38:42 2017', 'title': '[問卦] 果粉是不是M啊？？', 'author': 'tp943308 (尊爵不凡廢文王)', 'content': '\n用HTC的會頓使用者會說垃圾手機\n\n然後就換一支了\n\n蘋果黑屏閃退轉圈圈\n\n果粉會罵一罵然後繼續吹Ios系統多屌多屌\n\n果粉是不是都智障 M傾向？\n\n--\n'}
# {'date': 'Thu Dec 21 14:39:06 2017', 'title': 'Re: [新聞] 高雄低薪環境嚴重 網友嘆：住高雄的大學', 'author': 'Andrew90 (蒙那麗莎的偽笑)', 'content': '\n這種文看就知沒腦筋  房價高漲跟花媽啥關係??\n\n十年來 高雄人口仍然小增加\n\n而台北市近幾年大量外逃\n\n逃到新北 逃到桃園\n\n中部除台中以外 台中周遭那些縣市\n十年來你看掉多少人\n彰化 嘉義 南投 雲林 苗栗  慘慘慘\n這幾個縣市才是北上最多的人\n\n首都吸了大量資源 造成人民只能往首都移動  房價不漲才怪\n\n一坪均價60萬 剛好而已\n\n怪就怪政府 資源分配不均囉！\n\n\n\n'}
# {'date': 'Thu Dec 21 14:39:36 2017', 'title': 'Re: [問卦] 明年供電就會出事 怎麼推全面電動車', 'author': 'am711206 (阿爾提克斯)', 'content': '\n'}
# {'date': 'Thu Dec 21 14:41:47 2017', 'title': '[新聞] 鯨魚在海中怎麼睡覺？\u3000一次巧遇揭開神', 'author': 'Acalanatha30 (聊天室7起來)', 'content': '\n鯨魚睡覺也太可愛了吧XDDDD\n\n一天只睡1.7小時\n\n如果他們可以工作\n\n台灣的老闆樂翻了吧\n\n影片:'}
